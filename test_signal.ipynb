# %% [markdown]
# # Test iqtools make_signal

# %%
from iqtools import *
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
t, x = make_signal(10, 1000, nharm = 2, length=2, noise=0)

# %%
plt.plot(t, x, '-')
#markerline, stemlines, baseline = plt.stem(t, x, '-,')
#plt.setp(markerline, 'markerfacecolor', 'b')
#plt.setp(baseline, 'color','r', 'linewidth', 2)

# %%
f, p = get_pwelch(x, 1000)

# %%
plt.plot(f, 10*np.log(p*1000))
plt.grid(1)

# %%
y=np.fft.fft(x)

# %%
plt.plot(np.abs(y))

# %%
xbar, phas = make_analytical(x)

# %%
plot_hilbert(xbar)
