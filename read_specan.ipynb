# %% [markdown]
# # read Specan (xml) files

# %%
import numpy as np
import xml.etree.ElementTree as et
import matplotlib.pyplot as plt
from iqtools import *
# %matplotlib inline

# %%
filename = 'RSA51_238U90+190MeVu-2014.10.23.14.47.14.690.Specan'

# %%
f, p = read_result_xml(filename)

# %%
plt.plot(f, IQData.get_dbm(p))
