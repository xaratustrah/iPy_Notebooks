# %% [markdown]
# # Testing sample entropy

# %%
from sampen import sampen2
import numpy as np
import math
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
a = np.random.randint(200, size=1024, high=500)
plt.plot(a)

# %%
sampen2(a)
# Out:
# [(0, 5.725155707875543, 7.879810265523703e-05),
#  (1, 5.83305481036034, 0.0013080203428794375),
#  (2, None, None)]

# %%
x = np.linspace(0, 1, 100)
y = np.sin(2*math.pi / 0.2 * x)
plt.plot(x, y)

# %%
sampen2(y)
# Out:
# [(0, 1.7069727872605365, 0.007991296916336961),
#  (1, 0.5649974749081904, 0.049864846536996424),
#  (2, 0.25016533306684696, 0.018621610651233873)]

# %%
import peakutils

# %%
indexes = peakutils.indexes(y, thres=0.02/max(y), min_dist=100)

# %%
indexes
# Out:
# array([5])
