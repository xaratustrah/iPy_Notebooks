# %%
import scipy.io as sio
import numpy as np
import matplotlib.pyplot as plt
from sampen import sampen2
# %matplotlib inline

# %%
dat = sio.loadmat('sampledata.mat')

# %%
x = np.asarray(dat['x'])

# %%
plt.plot(x)
plt.grid()

# %%
sampen2(x)
# Out:
# [(0, 1.8095520938855616, 0.004616873547367554),
#  (1, 0.17050297481796714, 0.0025514735757105654),
#  (2, 0.14549059059591612, 0.002622955243679747)]
