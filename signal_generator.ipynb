# %%
from iqtools import *
# %matplotlib inline

# %%
freq = 400
center = 0
fs = 10000
duration = 3
t, x = make_test_signal(freq, fs, duration, nharm=3,noise=True )

# %%
plt.plot(t, x)

# %%
xbar, phase = make_analytical(x)

# %%
xbar
# Out:
# array([ 0.10595649-4.16241012j,  2.53235893-2.99194926j,
#         2.88931221-0.8066788j , ..., -3.56537826+0.68292677j,
#        -2.54627924-0.9796434j , -2.67626239-2.77989212j])

# %%
plot_hilbert(xbar)

# %%
write_signal_as_binary('/Users/shahab/test.bin', xbar, fs, center)

# %%
write_signal_as_ascii('/Users/shahab/test.csv', xbar, fs, center)
